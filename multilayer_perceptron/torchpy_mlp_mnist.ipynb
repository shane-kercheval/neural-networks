# %%
import time
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import fetch_openml
from sklearn.model_selection import train_test_split
import pandas as pd

# %%
SEED = 42
DIMENSIONS = (28, 28)
CHANNELS = 1  # grayscale
INPUT_SIZE = DIMENSIONS[0] * DIMENSIONS[1]
OUTPUT_SIZE = 10

def transform_data(
        is_convolutional: bool,
        x: pd.DataFrame,
        y: pd.Series | None = None) -> tuple[np.array, np.array]:
    """
    Transforms the data. Returns a tuple of (x, y) where x is a tensor of the features and y is a
    tensor of the labels.

    Args:
        is_convolutional: A boolean indicating whether the model is convolutional.
        x: A dataframe of the features.
        y: A series of the labels.
    """
    x = x.to_numpy()
    # Normalize the tensor
    x_min = x.min()
    x_max = x.max()
    x = (x - x_min) / (x_max - x_min)
    assert x.min() == 0
    assert x.max() == 1
    if is_convolutional:
        # Reshape data to have channel dimension
        # MNIST images are 28x28, so we reshape them to [batch_size, 1, 28, 28]
        x = x.reshape(-1, CHANNELS, DIMENSIONS[0], DIMENSIONS[1])
    if y is not None:
        y = y.to_numpy().astype(int)
    return x, y


def get_data():  # noqa
    """Function is required by and called from `model_pipeline()`."""
    x, y = fetch_openml('mnist_784', version=1, return_X_y=True, parser='auto')
    x, y = transform_data(is_convolutional=False, x=x, y=y)
    # 80% train; 10% validation; 10% test
    x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=SEED)
    x_test, x_val, y_test, y_val = train_test_split(x_test, y_test, test_size=0.5, random_state=SEED)  # noqa
    print(f"Training set  : X-{x_train.shape}, y-{y_train.shape}")
    print(f"Validation set: X-{x_val.shape}, y-{y_val.shape}")
    print(f"Test set      : X-{x_test.shape}, y-{y_test.shape}")
    return x_train, x_val, x_test, y_train, y_val, y_test

x_train, x_val, x_test, y_train, y_val, y_test = get_data()
# Out:
# Training set  : X-(56000, 784), y-(56000,)
# Validation set: X-(7000, 784), y-(7000,)
# Test set      : X-(7000, 784), y-(7000,)

# %%
from torchpy import net

learning_rate = 0.01
epochs = 15
batch_size = 32

rng = np.random.default_rng(SEED)
shuffle_index = rng.permutation(x_train.shape[0])
x_train, y_train = x_train[shuffle_index], y_train[shuffle_index]

model = net.Sequential([
    net.Linear(INPUT_SIZE, 100, weight_init_scale=net.he_init_scale),
    net.ReLU(),
    net.Linear(100, OUTPUT_SIZE, weight_init_scale=net.glorot_init_scale),
])

# Loss function and optimizer
loss_function = net.CrossEntropyLoss()
optimizer = net.SGD(learning_rate=learning_rate)

training_losses = []
validation_losses = []

start = time.time()
for epoch in range(epochs):
    for batch, i in enumerate(range(0, x_train.shape[0], batch_size)):
        x_batch = x_train[i:i+batch_size]
        y_batch = y_train[i:i+batch_size]
        with net.Module.training_mode():
            # Forward pass
            logits = model(x_batch)
            loss = loss_function(logits, y_batch)
            # Backward pass
            loss_grad = loss_function.backward()
            model.backward(loss_grad)
            model.step(optimizer)
        if batch % 400 == 0:
            training_losses.append(loss)
            # calculate validation loss
            val_loss = loss_function(logits=model(x_val), targets=y_val)
            validation_losses.append(val_loss)
            print(f"Epoch {epoch}, Batch {batch:04}, training loss {round(loss, 3)}, validation loss {round(val_loss, 3)}")  # noqa

end = time.time()
# Out:
# Epoch 0, Batch 0000, training loss 2.621, validation loss 2.52
# Epoch 0, Batch 0400, training loss 0.343, validation loss 0.544
# Epoch 0, Batch 0800, training loss 0.229, validation loss 0.41
# Epoch 0, Batch 1200, training loss 0.3, validation loss 0.362
# Epoch 0, Batch 1600, training loss 0.386, validation loss 0.329
# Epoch 1, Batch 0000, training loss 0.194, validation loss 0.324
# Epoch 1, Batch 0400, training loss 0.107, validation loss 0.305
# Epoch 1, Batch 0800, training loss 0.101, validation loss 0.289
# Epoch 1, Batch 1200, training loss 0.185, validation loss 0.279
# Epoch 1, Batch 1600, training loss 0.345, validation loss 0.267
# Epoch 2, Batch 0000, training loss 0.126, validation loss 0.266
# Epoch 2, Batch 0400, training loss 0.077, validation loss 0.259
# Epoch 2, Batch 0800, training loss 0.074, validation loss 0.25
# Epoch 2, Batch 1200, training loss 0.14, validation loss 0.245
# Epoch 2, Batch 1600, training loss 0.319, validation loss 0.237
# Epoch 3, Batch 0000, training loss 0.093, validation loss 0.237
# Epoch 3, Batch 0400, training loss 0.065, validation loss 0.233
# Epoch 3, Batch 0800, training loss 0.059, validation loss 0.226
# Epoch 3, Batch 1200, training loss 0.114, validation loss 0.223
# Epoch 3, Batch 1600, training loss 0.291, validation loss 0.217
# Epoch 4, Batch 0000, training loss 0.074, validation loss 0.217
# Epoch 4, Batch 0400, training loss 0.059, validation loss 0.214
# Epoch 4, Batch 0800, training loss 0.051, validation loss 0.208
# Epoch 4, Batch 1200, training loss 0.098, validation loss 0.207
# Epoch 4, Batch 1600, training loss 0.27, validation loss 0.202
# Epoch 5, Batch 0000, training loss 0.063, validation loss 0.202
# Epoch 5, Batch 0400, training loss 0.054, validation loss 0.2
# Epoch 5, Batch 0800, training loss 0.046, validation loss 0.195
# Epoch 5, Batch 1200, training loss 0.086, validation loss 0.194
# Epoch 5, Batch 1600, training loss 0.254, validation loss 0.19
# Epoch 6, Batch 0000, training loss 0.055, validation loss 0.19
# Epoch 6, Batch 0400, training loss 0.05, validation loss 0.188
# Epoch 6, Batch 0800, training loss 0.042, validation loss 0.184
# Epoch 6, Batch 1200, training loss 0.078, validation loss 0.183
# Epoch 6, Batch 1600, training loss 0.242, validation loss 0.18
# Epoch 7, Batch 0000, training loss 0.05, validation loss 0.179
# Epoch 7, Batch 0400, training loss 0.046, validation loss 0.178
# Epoch 7, Batch 0800, training loss 0.038, validation loss 0.175
# Epoch 7, Batch 1200, training loss 0.073, validation loss 0.174
# Epoch 7, Batch 1600, training loss 0.227, validation loss 0.171
# Epoch 8, Batch 0000, training loss 0.045, validation loss 0.171
# Epoch 8, Batch 0400, training loss 0.042, validation loss 0.17
# Epoch 8, Batch 0800, training loss 0.036, validation loss 0.167
# Epoch 8, Batch 1200, training loss 0.068, validation loss 0.166
# Epoch 8, Batch 1600, training loss 0.214, validation loss 0.164
# Epoch 9, Batch 0000, training loss 0.041, validation loss 0.164
# Epoch 9, Batch 0400, training loss 0.037, validation loss 0.163
# Epoch 9, Batch 0800, training loss 0.034, validation loss 0.16
# Epoch 9, Batch 1200, training loss 0.064, validation loss 0.16
# Epoch 9, Batch 1600, training loss 0.203, validation loss 0.158
# Epoch 10, Batch 0000, training loss 0.038, validation loss 0.157
# Epoch 10, Batch 0400, training loss 0.033, validation loss 0.157
# Epoch 10, Batch 0800, training loss 0.033, validation loss 0.154
# Epoch 10, Batch 1200, training loss 0.061, validation loss 0.154
# Epoch 10, Batch 1600, training loss 0.193, validation loss 0.152
# Epoch 11, Batch 0000, training loss 0.035, validation loss 0.152
# Epoch 11, Batch 0400, training loss 0.03, validation loss 0.151
# Epoch 11, Batch 0800, training loss 0.032, validation loss 0.149
# Epoch 11, Batch 1200, training loss 0.059, validation loss 0.149
# Epoch 11, Batch 1600, training loss 0.183, validation loss 0.147
# Epoch 12, Batch 0000, training loss 0.032, validation loss 0.147
# Epoch 12, Batch 0400, training loss 0.027, validation loss 0.146
# Epoch 12, Batch 0800, training loss 0.031, validation loss 0.144
# Epoch 12, Batch 1200, training loss 0.056, validation loss 0.144
# Epoch 12, Batch 1600, training loss 0.172, validation loss 0.142
# Epoch 13, Batch 0000, training loss 0.029, validation loss 0.142
# Epoch 13, Batch 0400, training loss 0.025, validation loss 0.142
# Epoch 13, Batch 0800, training loss 0.03, validation loss 0.14
# Epoch 13, Batch 1200, training loss 0.053, validation loss 0.14
# Epoch 13, Batch 1600, training loss 0.164, validation loss 0.138
# Epoch 14, Batch 0000, training loss 0.027, validation loss 0.138
# Epoch 14, Batch 0400, training loss 0.023, validation loss 0.138
# Epoch 14, Batch 0800, training loss 0.029, validation loss 0.136
# Epoch 14, Batch 1200, training loss 0.051, validation loss 0.136
# Epoch 14, Batch 1600, training loss 0.155, validation loss 0.134

# %%
print(f"Training took {round(end - start, 2)} seconds on via torchpy")
# Out:
# Training took 55.03 seconds on via torchpy

# %%
# plot losses over time
plt.plot(training_losses, label="Training loss")
plt.plot(validation_losses, label="Validation loss")
plt.ylim(0, 3)
plt.legend()

# %%
logits = model(x_test)
loss = loss_function(logits, y_test)
print(f"Test loss: {loss}")
# get index of highest probability in each row
predicted = np.argmax(logits, axis=1)
accuracy = (predicted == y_test).sum() / y_test.size
print(f"Test accuracy: {accuracy:.3f}")
# Out:
# Test loss: 0.1470596197897461
# Test accuracy: 0.959

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns

cm = confusion_matrix(y_test, predicted)
# remove the diagonal values (correct predictions) for better visualization
np.fill_diagonal(cm, 0)
fig = plt.figure(figsize=(OUTPUT_SIZE, OUTPUT_SIZE))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', cbar=False)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Count of Misclassified Samples by Class')
# Out:
# Text(0.5, 1.0, 'Count of Misclassified Samples by Class')

# %% [markdown]
# ---
