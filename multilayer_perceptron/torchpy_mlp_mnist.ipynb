# %%
import time
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import fetch_openml
from sklearn.model_selection import train_test_split
import pandas as pd
# Out:
# /tmp/ipykernel_84623/671612114.py:6: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
SEED = 42
DIMENSIONS = (28, 28)
CHANNELS = 1  # grayscale
INPUT_SIZE = DIMENSIONS[0] * DIMENSIONS[1]
OUTPUT_SIZE = 10

def transform_data(
        is_convolutional: bool,
        x: pd.DataFrame,
        y: pd.Series | None = None) -> tuple[np.array, np.array]:
    """
    Transforms the data. Returns a tuple of (x, y) where x is a tensor of the features and y is a
    tensor of the labels.

    Args:
        is_convolutional: A boolean indicating whether the model is convolutional.
        x: A dataframe of the features.
        y: A series of the labels.
    """
    x = x.to_numpy()
    # Normalize the tensor
    x_min = x.min()
    x_max = x.max()
    x = (x - x_min) / (x_max - x_min)
    assert x.min() == 0
    assert x.max() == 1
    if is_convolutional:
        # Reshape data to have channel dimension
        # MNIST images are 28x28, so we reshape them to [batch_size, 1, 28, 28]
        x = x.reshape(-1, CHANNELS, DIMENSIONS[0], DIMENSIONS[1])
    if y is not None:
        y = y.to_numpy().astype(int)
    return x, y


def get_data():  # noqa
    """Function is required by and called from `model_pipeline()`."""
    x, y = fetch_openml('mnist_784', version=1, return_X_y=True, parser='auto')
    x, y = transform_data(is_convolutional=False, x=x, y=y)
    # 80% train; 10% validation; 10% test
    x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=SEED)
    x_test, x_val, y_test, y_val = train_test_split(x_test, y_test, test_size=0.5, random_state=SEED)  # noqa
    print(f"Training set  : X-{x_train.shape}, y-{y_train.shape}")
    print(f"Validation set: X-{x_val.shape}, y-{y_val.shape}")
    print(f"Test set      : X-{x_test.shape}, y-{y_test.shape}")
    return x_train, x_val, x_test, y_train, y_val, y_test

x_train, x_val, x_test, y_train, y_val, y_test = get_data()
# Out:
# Training set  : X-(56000, 784), y-(56000,)
# Validation set: X-(7000, 784), y-(7000,)
# Test set      : X-(7000, 784), y-(7000,)

# %%
from torchpy import net

learning_rate = 0.01
epochs = 15
batch_size = 32

rng = np.random.default_rng(SEED)
shuffle_index = rng.permutation(x_train.shape[0])
x_train, y_train = x_train[shuffle_index], y_train[shuffle_index]


model = net.Sequential([
    net.Linear(INPUT_SIZE, 100, weight_init_scale=net.he_init_scale),
    net.ReLU(),
    net.Linear(100, OUTPUT_SIZE, weight_init_scale=net.glorot_init_scale),
    net.Softmax(),
])

# Loss function and optimizer
loss_function = net.CrossEntropyLoss()
optimizer = net.SGD(learning_rate=learning_rate)

training_losses = []
validation_losses = []

start = time.time()
for epoch in range(epochs):
    for batch, i in enumerate(range(0, x_train.shape[0], batch_size)):
        x_batch = x_train[i:i+batch_size]
        y_batch = y_train[i:i+batch_size]

        with net.Module.training_mode():
            # Forward pass
            predictions = model(x_batch)
            loss = loss_function(predictions, y_batch)
            # Backward pass
            loss_grad = loss_function.backward()
            model.backward(loss_grad)
            model.step(optimizer)
        if batch % 400 == 0:
            training_losses.append(loss)
            # calculate validation loss
            val_loss = loss_function(predictions=model(x_val), targets=y_val)
            validation_losses.append(val_loss)
            print(f"Epoch {epoch}, Batch {batch:04}, training loss {round(loss, 3)}, validation loss {round(val_loss, 3)}")  # noqa

end = time.time()
# Out:
# Epoch 0, Batch 0000, training loss 2.49, validation loss 2.5
# Epoch 0, Batch 0400, training loss 1.248, validation loss 1.467
# Epoch 0, Batch 0800, training loss 0.878, validation loss 0.994
# Epoch 0, Batch 1200, training loss 0.775, validation loss 0.761
# Epoch 0, Batch 1600, training loss 0.669, validation loss 0.641
# Epoch 1, Batch 0000, training loss 0.627, validation loss 0.611
# Epoch 1, Batch 0400, training loss 0.381, validation loss 0.554
# Epoch 1, Batch 0800, training loss 0.347, validation loss 0.51
# Epoch 1, Batch 1200, training loss 0.472, validation loss 0.48
# Epoch 1, Batch 1600, training loss 0.512, validation loss 0.456
# Epoch 2, Batch 0000, training loss 0.422, validation loss 0.448
# Epoch 2, Batch 0400, training loss 0.223, validation loss 0.433
# Epoch 2, Batch 0800, training loss 0.241, validation loss 0.416
# Epoch 2, Batch 1200, training loss 0.371, validation loss 0.404
# Epoch 2, Batch 1600, training loss 0.463, validation loss 0.392
# Epoch 3, Batch 0000, training loss 0.324, validation loss 0.388
# Epoch 3, Batch 0400, training loss 0.161, validation loss 0.382
# Epoch 3, Batch 0800, training loss 0.195, validation loss 0.372
# Epoch 3, Batch 1200, training loss 0.317, validation loss 0.365
# Epoch 3, Batch 1600, training loss 0.439, validation loss 0.357
# Epoch 4, Batch 0000, training loss 0.268, validation loss 0.355
# Epoch 4, Batch 0400, training loss 0.128, validation loss 0.352
# Epoch 4, Batch 0800, training loss 0.167, validation loss 0.344
# Epoch 4, Batch 1200, training loss 0.281, validation loss 0.34
# Epoch 4, Batch 1600, training loss 0.424, validation loss 0.334
# Epoch 5, Batch 0000, training loss 0.23, validation loss 0.333
# Epoch 5, Batch 0400, training loss 0.108, validation loss 0.331
# Epoch 5, Batch 0800, training loss 0.147, validation loss 0.325
# Epoch 5, Batch 1200, training loss 0.253, validation loss 0.322
# Epoch 5, Batch 1600, training loss 0.413, validation loss 0.317
# Epoch 6, Batch 0000, training loss 0.204, validation loss 0.316
# Epoch 6, Batch 0400, training loss 0.095, validation loss 0.316
# Epoch 6, Batch 0800, training loss 0.132, validation loss 0.31
# Epoch 6, Batch 1200, training loss 0.23, validation loss 0.308
# Epoch 6, Batch 1600, training loss 0.404, validation loss 0.304
# Epoch 7, Batch 0000, training loss 0.184, validation loss 0.303
# Epoch 7, Batch 0400, training loss 0.087, validation loss 0.303
# Epoch 7, Batch 0800, training loss 0.12, validation loss 0.298
# Epoch 7, Batch 1200, training loss 0.21, validation loss 0.297
# Epoch 7, Batch 1600, training loss 0.394, validation loss 0.293
# Epoch 8, Batch 0000, training loss 0.167, validation loss 0.292
# Epoch 8, Batch 0400, training loss 0.08, validation loss 0.293
# Epoch 8, Batch 0800, training loss 0.11, validation loss 0.288
# Epoch 8, Batch 1200, training loss 0.192, validation loss 0.287
# Epoch 8, Batch 1600, training loss 0.384, validation loss 0.284
# Epoch 9, Batch 0000, training loss 0.154, validation loss 0.283
# Epoch 9, Batch 0400, training loss 0.075, validation loss 0.284
# Epoch 9, Batch 0800, training loss 0.101, validation loss 0.28
# Epoch 9, Batch 1200, training loss 0.176, validation loss 0.279
# Epoch 9, Batch 1600, training loss 0.376, validation loss 0.276
# Epoch 10, Batch 0000, training loss 0.142, validation loss 0.275
# Epoch 10, Batch 0400, training loss 0.071, validation loss 0.276
# Epoch 10, Batch 0800, training loss 0.095, validation loss 0.272
# Epoch 10, Batch 1200, training loss 0.16, validation loss 0.271
# Epoch 10, Batch 1600, training loss 0.368, validation loss 0.269
# Epoch 11, Batch 0000, training loss 0.131, validation loss 0.268
# Epoch 11, Batch 0400, training loss 0.067, validation loss 0.269
# Epoch 11, Batch 0800, training loss 0.089, validation loss 0.266
# Epoch 11, Batch 1200, training loss 0.146, validation loss 0.265
# Epoch 11, Batch 1600, training loss 0.362, validation loss 0.262
# Epoch 12, Batch 0000, training loss 0.122, validation loss 0.262
# Epoch 12, Batch 0400, training loss 0.064, validation loss 0.263
# Epoch 12, Batch 0800, training loss 0.084, validation loss 0.259
# Epoch 12, Batch 1200, training loss 0.134, validation loss 0.259
# Epoch 12, Batch 1600, training loss 0.357, validation loss 0.256
# Epoch 13, Batch 0000, training loss 0.114, validation loss 0.256
# Epoch 13, Batch 0400, training loss 0.061, validation loss 0.257
# Epoch 13, Batch 0800, training loss 0.08, validation loss 0.254
# Epoch 13, Batch 1200, training loss 0.124, validation loss 0.253
# Epoch 13, Batch 1600, training loss 0.353, validation loss 0.251
# Epoch 14, Batch 0000, training loss 0.107, validation loss 0.25
# Epoch 14, Batch 0400, training loss 0.059, validation loss 0.251
# Epoch 14, Batch 0800, training loss 0.076, validation loss 0.248
# Epoch 14, Batch 1200, training loss 0.114, validation loss 0.248
# Epoch 14, Batch 1600, training loss 0.35, validation loss 0.245

# %%
print(f"Training took {round(end - start, 2)} seconds on via torchpy")
# Out:
# Training took 27.54 seconds on via torchpy

# %%
# plot losses over time
plt.plot(training_losses, label="Training loss")
plt.plot(validation_losses, label="Validation loss")
plt.ylim(0, 3)
plt.legend()

# %%
predictions = model(x_test)
loss = loss_function(predictions, y_test)
print(f"Test loss: {loss}")
# get index of highest probability in each row
predicted = np.argmax(predictions, axis=1)
accuracy = (predicted == y_test).sum() / y_test.size
print(f"Test accuracy: {accuracy:.3f}")
# Out:
# Test loss: 0.2708311475239806
# Test accuracy: 0.932

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns

cm = confusion_matrix(y_test, predicted)
# remove the diagonal values (correct predictions) for better visualization
np.fill_diagonal(cm, 0)
fig = plt.figure(figsize=(OUTPUT_SIZE, OUTPUT_SIZE))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', cbar=False)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Count of Misclassified Samples by Class')
# Out:
# Text(0.5, 1.0, 'Count of Misclassified Samples by Class')

# %% [markdown]
# ---

# %% [markdown]
# # Compare Pytorch CrossEntropyLoss() to Negative Log Likelihood calculated in numpy ipynb

# %%
def compute_loss(pred_probs: np.array, y: np.array) -> float:
    row_indices = np.arange(y.shape[0])
    column_indices = y#np.argmax(y, axis=1)
    pred_prob_of_actual = pred_probs[row_indices, column_indices]
    return -np.log(pred_prob_of_actual + 1e-9).mean()


# test/compare the loss from CrossEntryLoss with computed loss
cross_entropy_loss = loss_function(predictions, y_test)
computed_loss = compute_loss(predictions, y_test)
print(f"CrossEntropyLoss: {cross_entropy_loss:.3f}, Computed loss: {computed_loss:.3f}")
# Out:
# CrossEntropyLoss: 0.271, Computed loss: 0.271
