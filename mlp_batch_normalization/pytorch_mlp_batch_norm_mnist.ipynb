# %%
import time
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import fetch_openml
from sklearn.model_selection import train_test_split
import pandas as pd
import torch
# Out:
# /tmp/ipykernel_90989/3694697533.py:6: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
def get_available_device() -> str:
    """Returns the device based on the system configuration."""
    if torch.cuda.is_available():
        return torch.device('cuda').type
    if torch.backends.mps.is_available():
        return torch.device('mps').type  # https://pytorch.org/docs/stable/notes/mps.html
    return torch.device('cpu').type

device = get_available_device()
print(f"Using device: {device}")
# Out:
# Using device: cpu

# %%
DIMENSIONS = (28, 28)
CHANNELS = 1  # grayscale
INPUT_SIZE = DIMENSIONS[0] * DIMENSIONS[1]
OUTPUT_SIZE = 10

def transform_data(
        is_convolutional: bool,
        x: pd.DataFrame,
        y: pd.Series | None = None) -> tuple[torch.tensor, torch.tensor]:
    """
    Transforms the data. Returns a tuple of (x, y) where x is a tensor of the features and y is a
    tensor of the labels.

    Args:
        is_convolutional: A boolean indicating whether the model is convolutional.
        x: A dataframe of the features.
        y: A series of the labels.
    """
    x = torch.tensor(x.values, dtype=torch.float32)
    # Normalize the tensor
    x_min = x.min()
    x_max = x.max()
    x = (x - x_min) / (x_max - x_min)
    assert x.min() == 0
    assert x.max() == 1
    if is_convolutional:
        # Reshape data to have channel dimension
        # MNIST images are 28x28, so we reshape them to [batch_size, 1, 28, 28]
        x = x.reshape(-1, CHANNELS, DIMENSIONS[0], DIMENSIONS[1])
    if y is not None:
        y = torch.tensor(y.astype(int).values, dtype=torch.long)
    return x, y


def get_data():  # noqa
    """Function is required by and called from `model_pipeline()`."""
    x, y = fetch_openml('mnist_784', version=1, return_X_y=True, parser='auto')
    x, y = transform_data(is_convolutional=False, x=x, y=y)
    # 80% train; 10% validation; 10% test
    x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)
    x_test, x_val, y_test, y_val = train_test_split(x_test, y_test, test_size=0.5, random_state=42)
    print(f"Training set  : X-{x_train.shape}, y-{y_train.shape}")
    print(f"Validation set: X-{x_val.shape}, y-{y_val.shape}")
    print(f"Test set      : X-{x_test.shape}, y-{y_test.shape}")
    return x_train, x_val, x_test, y_train, y_val, y_test

x_train, x_val, x_test, y_train, y_val, y_test = get_data()
# Out:
# Training set  : X-torch.Size([56000, 784]), y-torch.Size([56000])
# Validation set: X-torch.Size([7000, 784]), y-torch.Size([7000])
# Test set      : X-torch.Size([7000, 784]), y-torch.Size([7000])

# %%
import torch
from torch import nn
from torch import optim
from torch.utils.data import DataLoader, TensorDataset

class MLP(nn.Module):
    """A Multilayer Perceptron (MLP) model in PyTorch with one hidden layer."""

    def __init__(self):
        super().__init__()
        self.layers = nn.Sequential(
            nn.Linear(INPUT_SIZE, 100),
            # THIS IS THE ONLY LINE THAT NEEDS TO CHANGE TO ADD BATCH NORMALIZATION
            nn.BatchNorm1d(100),  # Batch Normalization layer after the first Linear layer
            nn.ReLU(),
            nn.Linear(100, OUTPUT_SIZE),
        )

    def forward(self, x: torch.Tensor) -> torch.Tensor:
        """
        Forward pass through the network.

        Args:
            x: Input tensor.

        Returns:
            Tensor after passing through the layers and activations.
        """
        return self.layers(x)

learning_rate = 0.01
epochs = 15
batch_size = 32

x_train = x_train.to(device)
y_train = y_train.to(device)
x_val = x_val.to(device)
y_val = y_val.to(device)

dataset = TensorDataset(x_train, y_train)
dataloader = DataLoader(dataset, batch_size=batch_size, shuffle=True)

model = MLP()
model.to(device)
criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(model.parameters(), lr=learning_rate)
losses = []
val_losses = []

start = time.time()
for epoch in range(epochs):
    for batch, (inputs, targets) in enumerate(dataloader):
        optimizer.zero_grad()
        logits = model(inputs)
        loss = criterion(logits, targets)
        loss.backward()
        optimizer.step()
        if batch % 400 == 0:
            losses.append(loss.item())
            # calculate validation loss
            with torch.no_grad():
                val_outputs = model(x_val)
                val_loss = criterion(val_outputs, y_val)
                val_losses.append(val_loss.item())
            print(f"Epoch {epoch}, Batch {batch:04}, training loss {round(loss.item(), 3)}, validation loss {round(val_loss.item(), 3)}")  # noqa
end = time.time()
# Out:
# Epoch 0, Batch 0000, training loss 2.148, validation loss 2.227
# Epoch 0, Batch 0400, training loss 0.465, validation loss 0.459
# Epoch 0, Batch 0800, training loss 0.34, validation loss 0.341
# Epoch 0, Batch 1200, training loss 0.451, validation loss 0.29
# Epoch 0, Batch 1600, training loss 0.329, validation loss 0.263
# Epoch 1, Batch 0000, training loss 0.206, validation loss 0.254
# Epoch 1, Batch 0400, training loss 0.364, validation loss 0.235
# Epoch 1, Batch 0800, training loss 0.277, validation loss 0.22
# Epoch 1, Batch 1200, training loss 0.24, validation loss 0.21
# Epoch 1, Batch 1600, training loss 0.208, validation loss 0.197
# Epoch 2, Batch 0000, training loss 0.298, validation loss 0.194
# Epoch 2, Batch 0400, training loss 0.244, validation loss 0.184
# Epoch 2, Batch 0800, training loss 0.177, validation loss 0.18
# Epoch 2, Batch 1200, training loss 0.14, validation loss 0.173
# Epoch 2, Batch 1600, training loss 0.039, validation loss 0.167
# Epoch 3, Batch 0000, training loss 0.087, validation loss 0.166
# Epoch 3, Batch 0400, training loss 0.237, validation loss 0.159
# Epoch 3, Batch 0800, training loss 0.154, validation loss 0.157
# Epoch 3, Batch 1200, training loss 0.183, validation loss 0.153
# Epoch 3, Batch 1600, training loss 0.177, validation loss 0.148
# Epoch 4, Batch 0000, training loss 0.155, validation loss 0.146
# Epoch 4, Batch 0400, training loss 0.175, validation loss 0.145
# Epoch 4, Batch 0800, training loss 0.274, validation loss 0.14
# Epoch 4, Batch 1200, training loss 0.062, validation loss 0.136
# Epoch 4, Batch 1600, training loss 0.353, validation loss 0.135
# Epoch 5, Batch 0000, training loss 0.102, validation loss 0.135
# Epoch 5, Batch 0400, training loss 0.067, validation loss 0.132
# Epoch 5, Batch 0800, training loss 0.085, validation loss 0.13
# Epoch 5, Batch 1200, training loss 0.07, validation loss 0.127
# Epoch 5, Batch 1600, training loss 0.168, validation loss 0.125
# Epoch 6, Batch 0000, training loss 0.17, validation loss 0.125
# Epoch 6, Batch 0400, training loss 0.04, validation loss 0.124
# Epoch 6, Batch 0800, training loss 0.013, validation loss 0.121
# Epoch 6, Batch 1200, training loss 0.075, validation loss 0.121
# Epoch 6, Batch 1600, training loss 0.121, validation loss 0.118
# Epoch 7, Batch 0000, training loss 0.115, validation loss 0.119
# Epoch 7, Batch 0400, training loss 0.034, validation loss 0.118
# Epoch 7, Batch 0800, training loss 0.147, validation loss 0.114
# Epoch 7, Batch 1200, training loss 0.104, validation loss 0.113
# Epoch 7, Batch 1600, training loss 0.104, validation loss 0.112
# Epoch 8, Batch 0000, training loss 0.101, validation loss 0.11
# Epoch 8, Batch 0400, training loss 0.07, validation loss 0.11
# Epoch 8, Batch 0800, training loss 0.108, validation loss 0.109
# Epoch 8, Batch 1200, training loss 0.057, validation loss 0.109
# Epoch 8, Batch 1600, training loss 0.053, validation loss 0.105
# Epoch 9, Batch 0000, training loss 0.172, validation loss 0.105
# Epoch 9, Batch 0400, training loss 0.241, validation loss 0.105
# Epoch 9, Batch 0800, training loss 0.162, validation loss 0.108
# Epoch 9, Batch 1200, training loss 0.107, validation loss 0.105
# Epoch 9, Batch 1600, training loss 0.081, validation loss 0.104
# Epoch 10, Batch 0000, training loss 0.059, validation loss 0.104
# Epoch 10, Batch 0400, training loss 0.059, validation loss 0.103
# Epoch 10, Batch 0800, training loss 0.029, validation loss 0.104
# Epoch 10, Batch 1200, training loss 0.138, validation loss 0.101
# Epoch 10, Batch 1600, training loss 0.049, validation loss 0.101
# Epoch 11, Batch 0000, training loss 0.176, validation loss 0.1
# Epoch 11, Batch 0400, training loss 0.165, validation loss 0.101
# Epoch 11, Batch 0800, training loss 0.054, validation loss 0.099
# Epoch 11, Batch 1200, training loss 0.02, validation loss 0.098
# Epoch 11, Batch 1600, training loss 0.173, validation loss 0.099
# Epoch 12, Batch 0000, training loss 0.045, validation loss 0.098
# Epoch 12, Batch 0400, training loss 0.113, validation loss 0.1
# Epoch 12, Batch 0800, training loss 0.029, validation loss 0.096
# Epoch 12, Batch 1200, training loss 0.029, validation loss 0.097
# Epoch 12, Batch 1600, training loss 0.117, validation loss 0.095
# Epoch 13, Batch 0000, training loss 0.073, validation loss 0.093
# Epoch 13, Batch 0400, training loss 0.063, validation loss 0.095
# Epoch 13, Batch 0800, training loss 0.059, validation loss 0.093
# Epoch 13, Batch 1200, training loss 0.062, validation loss 0.093
# Epoch 13, Batch 1600, training loss 0.076, validation loss 0.094
# Epoch 14, Batch 0000, training loss 0.08, validation loss 0.093
# Epoch 14, Batch 0400, training loss 0.1, validation loss 0.094
# Epoch 14, Batch 0800, training loss 0.062, validation loss 0.094
# Epoch 14, Batch 1200, training loss 0.039, validation loss 0.091
# Epoch 14, Batch 1600, training loss 0.04, validation loss 0.091

# %%
print(f"Training took {round(end - start, 2)} seconds on {device}")
# Out:
# Training took 2017.67 seconds on cpu

# %%
# plot losses over time
plt.plot(losses, label="Training loss")
plt.plot(val_losses, label="Validation loss")
plt.ylim(0, 3)
plt.legend()

# %%
x_test = x_test.to(device)
y_test = y_test.to(device)

# test the model
with torch.no_grad():
    outputs = model(x_test)
    loss = criterion(outputs, y_test)
    print(f"Test loss: {loss}")
    _, predicted = torch.max(outputs, 1)
    accuracy = (predicted == y_test).sum().item() / y_test.size(0)
    print(f"Test accuracy: {accuracy:.3f}")
# Out:
# Test loss: 0.10677920281887054
# Test accuracy: 0.968

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns

cm = confusion_matrix(y_test.cpu(), predicted.cpu())
# remove the diagonal values (correct predictions) for better visualization
np.fill_diagonal(cm, 0)
fig = plt.figure(figsize=(OUTPUT_SIZE, OUTPUT_SIZE))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', cbar=False)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Count of Misclassified Samples by Class')
# Out:
# Text(0.5, 1.0, 'Count of Misclassified Samples by Class')

# %% [markdown]
# ---

# %% [markdown]
# # Compare Pytorch CrossEntropyLoss() to Negative Log Likelihood calculated in numpy ipynb

# %%
def compute_loss(pred_probs: np.array, y: np.array) -> float:
    row_indices = np.arange(y.shape[0])
    column_indices = y#np.argmax(y, axis=1)
    pred_prob_of_actual = pred_probs[row_indices, column_indices]
    return -np.log(pred_prob_of_actual + 1e-9).mean()

def softmax(x: np.array) -> np.array:
    exp_x = np.exp(x)
    return exp_x / exp_x.sum(axis=1).reshape(-1, 1)

criterion = nn.CrossEntropyLoss()

# test/compare the loss from CrossEntryLoss with computed loss
pred_probs = softmax(outputs.cpu().numpy())
# softmax
y = y_test.cpu().numpy()

cross_entropy_loss = criterion(outputs, y_test).item()
computed_loss = compute_loss(pred_probs, y)
print(f"CrossEntropyLoss: {cross_entropy_loss:.3f}, Computed loss: {computed_loss:.3f}")
# Out:
# CrossEntropyLoss: 0.107, Computed loss: 0.107
